# %% [markdown]
# <a href="https://colab.research.google.com/github/Chilanga02/DROUGHT-FORECASTING-IN-ZAMBIA/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tf_agents
# Out:
# Collecting tf_agents
#   Downloading tf_agents-0.10.0-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 14.9 MB/s
# Requirement already satisfied: gym>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.17.3)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (3.17.3)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from tf_agents) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (3.7.4.3)
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.15.0)
# Requirement already satisfied: gin-config>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.4.0)
# Requirement already satisfied: tensorflow-probability>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.14.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.0->tf_agents) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.0->tf_agents) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym>=0.17.0->tf_agents) (0.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.13.0->tf_agents) (0.1.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.13.0->tf_agents) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.13.0->tf_agents) (0.4.0)
# Installing collected packages: tf-agents
# Successfully installed tf-agents-0.10.0

# %%
from tf_agents.networks import actor_distribution_network, value_network
from tf_agents.networks import actor_distribution_rnn_network, value_rnn_network
import tensorflow as tf

from tensorflow._api.v2.compat.v1 import train
from tf_agents.environments import suite_gym, tf_py_environment
import tensorflow as tf
from tf_agents.agents.ppo import ppo_agent, ppo_clip_agent
from tf_agents.trajectories import trajectory
from tf_agents.utils import common
from tf_agents.drivers import dynamic_episode_driver
from tf_agents.replay_buffers import tf_uniform_replay_buffer

import matplotlib.pyplot as plt
import numpy as np

# %%
def create_networks(tf_env, lstm=True):
	actor_fc_layers = (512, 256, 64)
	value_fc_layers = (512, 256, 64)
	# last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
	if lstm:
		print('Enable LSTM')
		lstm_size = (5,)
		actor_net = actor_distribution_rnn_network.ActorDistributionRnnNetwork(tf_env.observation_spec(), tf_env.action_spec(), input_fc_layer_params=actor_fc_layers, lstm_size=lstm_size, output_fc_layer_params=None)
		value_net = value_rnn_network.ValueRnnNetwork(tf_env.observation_spec(),input_fc_layer_params=value_fc_layers, lstm_size=lstm_size, output_fc_layer_params=None)
	else:
		print('Disable LSTM')
		actor_net = actor_distribution_network.ActorDistributionNetwork(tf_env.observation_spec(), tf_env.action_spec(), fc_layer_params=actor_fc_layers, activation_fn=tf.keras.activations.tanh)
		value_net = value_network.ValueNetwork(tf_env.observation_spec(), fc_layer_params=value_fc_layers, activation_fn=tf.keras.activations.tanh)

	return actor_net, value_net

# %%
# env_name='LunarLander-v2'
# env_name = 'CartPole-v0'
env_name = 'Pendulum-v0'

train_py_env = suite_gym.load(env_name)
eval_py_env = suite_gym.load(env_name)
train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

learning_rate = 1e-3

optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)
actor_net, value_net = create_networks(train_env, lstm=False)

train_step_counter = tf.Variable(0)


tf_agent = ppo_clip_agent.PPOClipAgent(
	train_env.time_step_spec(),
	train_env.action_spec(),
	optimizer,
  greedy_eval=False,
	actor_net=actor_net,
	value_net=value_net,
	gradient_clipping=0.5,
	entropy_regularization=0.0,
	importance_ratio_clipping=0.2, #how far away the new policy can go from the old while still profiting the objective
	normalize_observations=False,
  normalize_rewards=False,
  use_gae=True,
  use_td_lambda_return=True,
  num_epochs=20,
  debug_summaries=False,
  summarize_grads_and_vars=False,
  train_step_counter=train_step_counter
    )

tf_agent.initialize()

replay_buffer_capacity=5000
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
        tf_agent.collect_data_spec,
        batch_size=train_env.batch_size, #num_parallel_environments
        max_length=replay_buffer_capacity)


# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []
total_episodes = 5000

collect_policy = tf_agent.collect_policy
eval_policy = tf_agent.policy

collect_episodes_per_iteration=5
collect_driver = dynamic_episode_driver.DynamicEpisodeDriver(
        train_env,
        collect_policy,
        observers=[replay_buffer.add_batch],
        num_episodes=collect_episodes_per_iteration)

for episode in range(total_episodes):
  collect_driver.run()
  trajectories = replay_buffer.gather_all()
  train_loss, extra = tf_agent.train(experience=trajectories)
  print(f'Episode = {episode}; Train loss = {train_loss}')
  step = tf_agent.train_step_counter.numpy()
  replay_buffer.clear()

  prev_time_step = eval_env.reset()
  # prev_time_step = train_env.reset() # For collect policy visualization
  episodic_reward = 0

  while True:
    # eval_env.render()
    action_step = eval_policy.action(prev_time_step, eval_policy.get_initial_state(batch_size=1))
    # action_step = collect_policy.action(prev_time_step, collect_policy.get_initial_state(batch_size=1)) # Run collect policy
    time_step = eval_env.step(action_step.action)
    # time_step = train_env.step(action_step.action) # Run collect policy

    episodic_reward += time_step.reward[0]
    # End this episode if Last Step
    if time_step.is_last():
      break

    prev_time_step = time_step

    ep_reward_list.append(episodic_reward)
    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-40:])

  print("Episode * {} * Avg Reward is ==> {}".format(episode, avg_reward))
  avg_reward_list.append(avg_reward)

# Plotting graph
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()

# Episode = 26; Train loss = 28.558256149291992
# Episode * 26 * Avg Reward is ==> 179.5
# Episode = 27; Train loss = 52.14350891113281
# Episode * 27 * Avg Reward is ==> 179.5
# Out:
# WARNING:absl:Only tf.keras.optimizers.Optimiers are well supported, got a non-TF2 optimizer: <tensorflow.python.training.adam.AdamOptimizer object at 0x7f56c2653dd0>
# Disable LSTM
# Episode = 0; Train loss = 4834.974609375
# Episode * 0 * Avg Reward is ==> -1252.340087890625
# Episode = 1; Train loss = 7618.11669921875
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7f56a877e8d0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 448, in body
#     return (time + 1, next_state, output_tas)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 870, in map_structure
#     expand_composites=expand_composites)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 869, in <listcomp>
#     structure[0], [func(*x) for x in entries],  File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 445, in <lambda>
#     output_tas = tf.nest.map_structure(lambda ta, x: ta.write(time, x),  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 249, in wrapped
#     error_in_function=error_in_function)
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7f56a877e8d0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 448, in body
#     return (time + 1, next_state, output_tas)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 870, in map_structure
#     expand_composites=expand_composites)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 869, in <listcomp>
#     structure[0], [func(*x) for x in entries],  File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 445, in <lambda>
#     output_tas = tf.nest.map_structure(lambda ta, x: ta.write(time, x),  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 249, in wrapped
#     error_in_function=error_in_function)
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7f56ba04c4d0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 448, in body
#     return (time + 1, next_state, output_tas)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 870, in map_structure
#     expand_composites=expand_composites)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 869, in <listcomp>
#     structure[0], [func(*x) for x in entries],  File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 445, in <lambda>
#     output_tas = tf.nest.map_structure(lambda ta, x: ta.write(time, x),  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 249, in wrapped
#     error_in_function=error_in_function)
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7f56ba04c4d0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 448, in body
#     return (time + 1, next_state, output_tas)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 870, in map_structure
#     expand_composites=expand_composites)  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py", line 869, in <listcomp>
#     structure[0], [func(*x) for x in entries],  File "/usr/local/lib/python3.7/dist-packages/tf_agents/keras_layers/dynamic_unroll_layer.py", line 445, in <lambda>
#     output_tas = tf.nest.map_structure(lambda ta, x: ta.write(time, x),  File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/tf_should_use.py", line 249, in wrapped
#     error_in_function=error_in_function)
# ==================================
# Episode * 1 * Avg Reward is ==> -1234.322509765625
# Episode = 2; Train loss = 7116.607421875
# Episode * 2 * Avg Reward is ==> -1292.678955078125
# Episode = 3; Train loss = 7467.17236328125
# Episode * 3 * Avg Reward is ==> -1091.399169921875
# Episode = 4; Train loss = 6981.92578125
# Episode * 4 * Avg Reward is ==> -1366.2861328125
# Episode = 5; Train loss = 7880.861328125
# Episode * 5 * Avg Reward is ==> -1612.9879150390625
# Episode = 6; Train loss = 7030.80810546875
# Episode * 6 * Avg Reward is ==> -1205.552978515625
# Episode = 7; Train loss = 7674.97265625
# Episode * 7 * Avg Reward is ==> -1675.293701171875
# Episode = 8; Train loss = 6755.35546875
# Episode * 8 * Avg Reward is ==> -1141.226318359375
# Episode = 9; Train loss = 7375.142578125
# Episode * 9 * Avg Reward is ==> -1070.953369140625
# Episode = 10; Train loss = 7582.228515625
# Episode * 10 * Avg Reward is ==> -1412.6181640625
# Episode = 11; Train loss = 6429.0029296875
# Episode * 11 * Avg Reward is ==> -1676.8804931640625
# Episode = 12; Train loss = 6786.29833984375
# Episode * 12 * Avg Reward is ==> -1076.787841796875
# Episode = 13; Train loss = 6765.3056640625
# Episode * 13 * Avg Reward is ==> -1353.8675537109375
# Episode = 14; Train loss = 6949.58642578125
# Episode * 14 * Avg Reward is ==> -1465.914306640625
# Episode = 15; Train loss = 7147.0400390625
# Episode * 15 * Avg Reward is ==> -1060.31591796875
# Episode = 16; Train loss = 6658.18115234375
# Episode * 16 * Avg Reward is ==> -1176.542724609375
# Episode = 17; Train loss = 5851.39306640625
# Episode * 17 * Avg Reward is ==> -1558.889892578125
# Episode = 18; Train loss = 6707.7109375
# Episode * 18 * Avg Reward is ==> -1213.0999755859375
# Episode = 19; Train loss = 6593.4365234375
# Episode * 19 * Avg Reward is ==> -1359.492431640625
# Episode = 20; Train loss = 6281.0947265625
# Episode * 20 * Avg Reward is ==> -1150.0660400390625
# Episode = 21; Train loss = 6293.0732421875
# Episode * 21 * Avg Reward is ==> -1460.98779296875
# Episode = 22; Train loss = 6694.69384765625
# Episode * 22 * Avg Reward is ==> -1623.9945068359375
# Episode = 23; Train loss = 5468.802734375
# Episode * 23 * Avg Reward is ==> -1526.647705078125
# Episode = 24; Train loss = 4427.0859375
# Episode * 24 * Avg Reward is ==> -825.3494873046875
# Episode = 25; Train loss = 4327.42822265625
# Episode * 25 * Avg Reward is ==> -1183.7144775390625
# Episode = 26; Train loss = 4500.81494140625
# Episode * 26 * Avg Reward is ==> -941.3699951171875
# Episode = 27; Train loss = 6287.49609375
# Episode * 27 * Avg Reward is ==> -1251.770751953125
# Episode = 28; Train loss = 5624.40673828125
# Episode * 28 * Avg Reward is ==> -1266.7989501953125
# Episode = 29; Train loss = 5383.71240234375
# Episode * 29 * Avg Reward is ==> -1178.4176025390625
# Episode = 30; Train loss = 6292.34619140625
# Episode * 30 * Avg Reward is ==> -1670.769287109375
# Episode = 31; Train loss = 4311.3857421875
# Episode * 31 * Avg Reward is ==> -992.0531005859375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-4cd655007b95> in <module>()
#      62
#      63 for episode in range(total_episodes):
# ---> 64   collect_driver.run()
#      65   trajectories = replay_buffer.gather_all()
#      66   train_loss, extra = tf_agent.train(experience=trajectories)
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/drivers/dynamic_episode_driver.py in run(self, time_step, policy_state, num_episodes, maximum_iterations)
#     213         policy_state=policy_state,
#     214         num_episodes=num_episodes,
# --> 215         maximum_iterations=maximum_iterations)
#     216
#     217   def _run(self,
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/utils/common.py in with_check_resource_vars(*fn_args, **fn_kwargs)
#     186         # We're either in eager mode or in tf.function mode (no in-between); so
#     187         # autodep-like behavior is already expected of fn.
# --> 188         return fn(*fn_args, **fn_kwargs)
#     189       if not resource_variables_enabled():
#     190         raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/drivers/dynamic_episode_driver.py in _run(self, time_step, policy_state, num_episodes, maximum_iterations)
#     242             parallel_iterations=1,
#     243             maximum_iterations=maximum_iterations,
# --> 244             name='driver_loop'))
#     245
#     246     return time_step, policy_state
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     615                   func.__module__, arg_name, arg_value, 'in a future version'
#     616                   if date is None else ('after %s' % date), instructions)
# --> 617       return func(*args, **kwargs)
#     618
#     619     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2539       name=name,
#    2540       maximum_iterations=maximum_iterations,
# -> 2541       return_same_structure=True)
#    2542
#    2543
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2775                                               list(loop_vars))
#    2776       while cond(*loop_vars):
# -> 2777         loop_vars = body(*loop_vars)
#    2778         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2779           packed = True
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/drivers/dynamic_episode_driver.py in loop_body(counter, time_step, policy_state)
#     132         loop_vars for next iteration of tf.while_loop.
#     133       """
# --> 134       action_step = self.policy.action(time_step, policy_state)
#     135
#     136       # TODO(b/134487572): TF2 while_loop seems to either ignore
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/policies/tf_policy.py in action(self, time_step, policy_state, seed)
#     322     if self._automatic_state_reset:
#     323       policy_state = self._maybe_reset_state(time_step, policy_state)
# --> 324     step = action_fn(time_step=time_step, policy_state=policy_state, seed=seed)
#     325
#     326     def clip_action(action, action_spec):
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/utils/common.py in with_check_resource_vars(*fn_args, **fn_kwargs)
#     186         # We're either in eager mode or in tf.function mode (no in-between); so
#     187         # autodep-like behavior is already expected of fn.
# --> 188         return fn(*fn_args, **fn_kwargs)
#     189       if not resource_variables_enabled():
#     190         raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/policies/tf_policy.py in _action(self, time_step, policy_state, seed)
#     558     """
#     559     seed_stream = tfp.util.SeedStream(seed=seed, salt='tf_agents_tf_policy')
# --> 560     distribution_step = self._distribution(time_step, policy_state)  # pytype: disable=wrong-arg-types
#     561     actions = tf.nest.map_structure(
#     562         lambda d: reparameterized_sampling.sample(d, seed=seed_stream()),
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/agents/ppo/ppo_policy.py in _distribution(self, time_step, policy_state, training)
#     249     (distributions, new_policy_state['actor_network_state']) = (
#     250         self._apply_actor_network(
# --> 251             time_step, policy_state['actor_network_state'], training=training))
#     252
#     253     if self._collect:
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/agents/ppo/ppo_policy.py in _apply_actor_network(self, time_step, policy_state, training)
#     225         time_step.step_type,
#     226         network_state=policy_state,
# --> 227         training=training)
#     228
#     229   def _variables(self):
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/network.py in __call__(self, inputs, *args, **kwargs)
#     424       normalized_kwargs.pop("network_state", None)
#     425
# --> 426     outputs, new_state = super(Network, self).__call__(**normalized_kwargs)
#     427
#     428     nest_utils.assert_matching_dtypes_and_inner_shapes(
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/actor_distribution_network.py in call(self, observations, step_type, network_state, training, mask)
#     195
#     196     output_actions = tf.nest.map_structure(
# --> 197         call_projection_net, self._projection_networks)
#     198     return output_actions, network_state
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/actor_distribution_network.py in call_projection_net(proj_net)
#     191     def call_projection_net(proj_net):
#     192       distribution, _ = proj_net(
# --> 193           state, outer_rank, training=training, mask=mask)
#     194       return distribution
#     195
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/network.py in __call__(self, inputs, *args, **kwargs)
#     424       normalized_kwargs.pop("network_state", None)
#     425
# --> 426     outputs, new_state = super(Network, self).__call__(**normalized_kwargs)
#     427
#     428     nest_utils.assert_matching_dtypes_and_inner_shapes(
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/normal_projection_network.py in call(self, inputs, outer_rank, training, mask)
#     209     stds = batch_squash.unflatten(stds)
#     210
# --> 211     return self.output_spec.build_distribution(loc=means, scale=stds), ()
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/specs/distribution_spec.py in build_distribution(self, **distribution_parameters)
#      87     kwargs = self._distribution_parameters.copy()
#      88     kwargs.update(distribution_parameters)
# ---> 89     return self._builder(**kwargs)
#      90
#      91   def __repr__(self):
#
# /usr/local/lib/python3.7/dist-packages/tf_agents/networks/normal_projection_network.py in distribution_builder(*args, **kwargs)
#     161         kwargs['scale_diag'] = kwargs['scale']
#     162         del kwargs['scale']
# --> 163         distribution = tfp.distributions.MultivariateNormalDiag(*args, **kwargs)
#     164       else:
#     165         distribution = tfp.distributions.Normal(*args, **kwargs)
#
# <decorator-gen-416> in __init__(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/distribution.py in wrapped_init(***failed resolving arguments***)
#     343       # called, here is the place to do it.
#     344       self_._parameters = None
# --> 345       default_init(self_, *args, **kwargs)
#     346       # Note: if we ever want to override things set in `self` by subclass
#     347       # `__init__`, here is the place to do it.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     547                 'in a future version' if date is None else ('after %s' % date),
#     548                 instructions)
# --> 549       return func(*args, **kwargs)
#     550
#     551     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/mvn_diag.py in __init__(self, loc, scale_diag, scale_identity_multiplier, validate_args, allow_nan_stats, experimental_use_kahan_sum, name)
#     274           allow_nan_stats=allow_nan_stats,
#     275           experimental_use_kahan_sum=experimental_use_kahan_sum,
# --> 276           name=name)
#     277       self._parameters = parameters
#     278
#
# <decorator-gen-332> in __init__(self, loc, scale, validate_args, allow_nan_stats, experimental_use_kahan_sum, name)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/distribution.py in wrapped_init(***failed resolving arguments***)
#     343       # called, here is the place to do it.
#     344       self_._parameters = None
# --> 345       default_init(self_, *args, **kwargs)
#     346       # Note: if we ever want to override things set in `self` by subclass
#     347       # `__init__`, here is the place to do it.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/mvn_linear_operator.py in __init__(self, loc, scale, validate_args, allow_nan_stats, experimental_use_kahan_sum, name)
#     224         bijector=bijector,
#     225         validate_args=validate_args,
# --> 226         name=name)
#     227     self._parameters = parameters
#     228
#
# <decorator-gen-286> in __init__(self, distribution, bijector, kwargs_split_fn, validate_args, parameters, name)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/distribution.py in wrapped_init(***failed resolving arguments***)
#     343       # called, here is the place to do it.
#     344       self_._parameters = None
# --> 345       default_init(self_, *args, **kwargs)
#     346       # Note: if we ever want to override things set in `self` by subclass
#     347       # `__init__`, here is the place to do it.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/transformed_distribution.py in __init__(self, distribution, bijector, kwargs_split_fn, validate_args, parameters, name)
#     239       # joint but don't inherit from JD. The 'duck-type' test is that
#     240       # JDs have a structured dtype.
# --> 241       dtype = self.bijector.forward_dtype(self.distribution.dtype)
#     242       self._is_joint = tf.nest.is_nested(dtype)
#     243
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/bijector.py in forward_dtype(self, dtype, name, **kwargs)
#    1691             check_types=False)
#    1692
# -> 1693       output_dtype = self._forward_dtype(input_dtype, **kwargs)
#    1694       try:
#    1695         # kwargs may alter dtypes themselves, but we currently require
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/composition.py in _forward_dtype(self, x, **kwargs)
#     643     return self._call_walk_forward(
#     644         lambda b, x, **kwds: b.forward_dtype(x, **kwds),
# --> 645         x, **kwargs)
#     646
#     647   def _inverse_dtype(self, y, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/composition.py in _call_walk_forward(self, step_fn, *args, **kwargs)
#     292
#     293     if len(args) == 1:
# --> 294       return self._walk_forward(step_fn, *args, **kwargs)
#     295
#     296     # Convert a tuple of structures to a structure of tuples. This
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/chain.py in _walk_forward(self, step_fn, x, **kwargs)
#     144     """Applies `transform_fn` to `x` sequentially over nested bijectors."""
#     145     for bij in reversed(self._bijectors):
# --> 146       x = step_fn(bij, x, **kwargs.get(bij.name, {}))
#     147     return x  # Now `y`
#     148
#
# KeyboardInterrupt:
